# %% [markdown]
# ## 01. Import dataset
#
# "billboard_dataset.csv" is a csv file originated from Dhruvil Dave's [Billboard "The Hot 100" Songs](https://www.kaggle.com/datasets/dhruvildave/billboard-the-hot-100-songs) which contains the collection of all "The Hot 100" charts released since its inception in 1958 until 2021-11-06.
#
# <br>
#
# I made two modifications on the original dataset.
#
# 1. I reduced the data range to cover from January 2, 2016, to November 6, 2021, due to Spotify's API rate limits for artist genre queries. This modification, however, does not affect my thesis, which examines changes in popularity before and after COVID-19.
#
# 2. I arranged the dates in descending order to better visualize the changes in popularity over time.

# %%
import pandas as pd

input_file = "billboard_dataset.csv"

try:
    df = pd.read_csv(input_file, on_bad_lines='skip', encoding='latin1')
except Exception as e:
    print(e)

# %%
df.head(20)
# Out:
#           date  rank                             song  \
# 0   2016-01-02     1                            Hello
# 1   2016-01-02     2                            Sorry
# 2   2016-01-02     3                    Hotline Bling
# 3   2016-01-02     4                    Love Yourself
# 4   2016-01-02     5                What Do You Mean?
# 5   2016-01-02     6                    Same Old Love
# 6   2016-01-02     7                        The Hills
# 7   2016-01-02     8                             Here
# 8   2016-01-02     9                         Stitches
# 9   2016-01-02    10          Like I'm Gonna Lose You
# 10  2016-01-02    11                              679
# 11  2016-01-02    12                     In The Night
# 12  2016-01-02    13                          Jumpman
# 13  2016-01-02    14                       On My Mind
# 14  2016-01-02    15               Can't Feel My Face
# 15  2016-01-02    16                         Antidote
# 16  2016-01-02    17                      Ex's & Oh's
# 17  2016-01-02    18  All I Want For Christmas Is You
# 18  2016-01-02    19                     Stressed Out
# 19  2016-01-02    20                            Don't
#
#                                   artist  last-week  peak-rank  weeks-on-board
# 0                                  Adele        1.0          1               8
# 1                          Justin Bieber        2.0          2               8
# 2                                  Drake        3.0          2              20
# 3                          Justin Bieber        5.0          4               5
# 4                          Justin Bieber        4.0          1              16
# 5                           Selena Gomez        9.0          6              14
# 6                             The Weeknd        6.0          1              30
# 7                           Alessia Cara        8.0          8              20
# 8                           Shawn Mendes        7.0          4              30
# 9   Meghan Trainor Featuring John Legend       10.0          8              24
# 10         Fetty Wap Featuring Remy Boyz       11.0          4              25
# 11                            The Weeknd       19.0         12               6
# 12                        Drake & Future       14.0         12              13
# 13                        Ellie Goulding       13.0         13              13
# 14                            The Weeknd       15.0          1              28
# 15                          Travis Scott       16.0         16              15
# 16                             Elle King       12.0         10              24
# 17                          Mariah Carey       22.0         18              13
# 18                     twenty one pilots       28.0         19              13
# 19                         Bryson Tiller       20.0         20              12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30600 entries, 0 to 30599
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            30600 non-null  object
#  1   rank            30600 non-null  int64
#  2   song            30600 non-null  object
#  3   artist          30600 non-null  object
#  4   last-week       26534 non-null  float64
#  5   peak-rank       30600 non-null  int64
#  6   weeks-on-board  30600 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 02. Preprocess given data

# %%
import pandas as pd

output_file = "preprocessed_billboard_data.csv"

# artist column       
df['artist'] = df['artist'].str.strip()
df['artist'] = df['artist'].apply(lambda x: str(x).split('Featuring')[0])
df['artist'] = df['artist'].apply(lambda x: str(x).split('&')[0])
df['artist'] = df['artist'].apply(lambda x: str(x).split('x')[0])
df['artist'] = df['artist'].apply(lambda x: str(x).split('X')[0])
df['artist'] = df['artist'].str.replace('"', '')

# drop unnecessary columns
features_drop = ['last-week', 'peak-rank', 'weeks-on-board']
df.drop(features_drop, axis=1, inplace=True)

# %%
df.head(20)
# Out:
#           date  rank                             song             artist
# 0   2016-01-02     1                            Hello              Adele
# 1   2016-01-02     2                            Sorry      Justin Bieber
# 2   2016-01-02     3                    Hotline Bling              Drake
# 3   2016-01-02     4                    Love Yourself      Justin Bieber
# 4   2016-01-02     5                What Do You Mean?      Justin Bieber
# 5   2016-01-02     6                    Same Old Love       Selena Gomez
# 6   2016-01-02     7                        The Hills         The Weeknd
# 7   2016-01-02     8                             Here       Alessia Cara
# 8   2016-01-02     9                         Stitches       Shawn Mendes
# 9   2016-01-02    10          Like I'm Gonna Lose You    Meghan Trainor
# 10  2016-01-02    11                              679         Fetty Wap
# 11  2016-01-02    12                     In The Night         The Weeknd
# 12  2016-01-02    13                          Jumpman             Drake
# 13  2016-01-02    14                       On My Mind     Ellie Goulding
# 14  2016-01-02    15               Can't Feel My Face         The Weeknd
# 15  2016-01-02    16                         Antidote       Travis Scott
# 16  2016-01-02    17                      Ex's & Oh's          Elle King
# 17  2016-01-02    18  All I Want For Christmas Is You       Mariah Carey
# 18  2016-01-02    19                     Stressed Out  twenty one pilots
# 19  2016-01-02    20                            Don't      Bryson Tiller

# %% [markdown]
# ## 03. Use Spotify API to get the genre information of each artists.
#
# note: Unfortunately, I could not find a way to get the genre of the song itself. So as an alternative, I used Spotify's API to get the genre information of an aritst.

# %%
import requests
import base64
from dotenv import load_dotenv
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy


load_dotenv()

def get_access_token(client_id, client_secret):
    auth_url = 'https://accounts.spotify.com/api/token'
    auth_headers = {
        'Authorization': 'Basic ' + base64.b64encode((client_id + ':' + client_secret).encode()).decode()
    }
    auth_data = {
        'grant_type': 'client_credentials'
    }

    response = requests.post(auth_url, headers=auth_headers, data=auth_data)

    if response.status_code == 200:
        token = response.json()['access_token']
        print(f"Access token generated successfully: {token[:5]}...")
        return token
    else:
        return 'Error:', response.status_code


def spotify_auth(client_id, client_secret):
    access_token = get_access_token(client_id, client_secret)
    try:
        client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
        sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
        print("Spotify authentication successful")
        return (access_token, sp)
    
    except spotipy.oauth2.SpotifyOauthError as e:
        print(f"Error: {e}")
        exit(1)


def get_artist_genres(artist, song, access_token, sp):
    try:
        # search for artist id
        # improved search by enhancing the query
        query = f"track:{song} artist:{artist}"
        result = sp.search(q=query, type='track', limit=1, offset=0)
        artist_id = result['tracks']['items'][0]['artists'][0]['id'] if result['tracks']['items'] else None

        if not artist_id:
             return None
        
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        # get artist information using artist id
        response = requests.get("https://api.spotify.com/v1/artists/{id}".format(id=artist_id), headers=headers)
        data = response.json()
        return data["genres"]
    except spotipy.SpotifyException as e:
        print(f"Error: {e}")
        return None

# %% [markdown]
# 현재 여기까지 진행
#
# 많은 artist의 genre 가 빈 list 형태로 나오고 있는중. Spotify API 측에서 변경이 일어난 것으로 확인됨.
#
# 관련 이슈: https://github.com/jpotw/billboard_genre_analysis/issues/1

# %%
import pandas as pd
import os


client_id = os.getenv('CLIENT_ID')
client_secret = os.getenv('CLIENT_SECRET')
access_token, sp = spotify_auth(client_id, client_secret)

df['genres'] = None

for artist in df['artist'].unique():
    try:
        song = list(df.loc[df['artist'] == artist, 'song'])[0]
        genres = get_artist_genres(artist, song, access_token, sp)
        if genres:
            df.loc[df['artist'] == artist, 'genres'] = genres * len(df[df['artist'] == artist])
        else:
            df[df['artist'] == artist]['genres'] = None
        print(f"Genres retrieved for {artist}: {genres}")
    except ValueError as e:
        print(f"Error retrieving genres for {artist}: {e}")
# Out:
# Access token generated successfully: BQBos...
# Spotify authentication successful
# Genres retrieved for Adele: ['soft pop']
# Genres retrieved for Justin Bieber: []
# C:\Users\USER\AppData\Local\Temp\ipykernel_30888\1098976983.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['artist'] == artist]['genres'] = None
# Error retrieving genres for Drake: Must have equal len keys and value when setting with an iterable
# Genres retrieved for Selena Gomez: ['pop']
# Genres retrieved for The Weeknd: []
# C:\Users\USER\AppData\Local\Temp\ipykernel_30888\1098976983.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['artist'] == artist]['genres'] = None
# Genres retrieved for Alessia Cara: []
# C:\Users\USER\AppData\Local\Temp\ipykernel_30888\1098976983.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['artist'] == artist]['genres'] = None
# Genres retrieved for Shawn Mendes: ['pop']

# %% [markdown]
# ## 04. Simplify Multiple genres into common genres

# %%
def convert_song_genres(batch):
    """
    converts the genre of all the songs in a single batch (size of 100) to simplified genres
    """
    batch['genres'] = batch['genres'].apply(simplify_genres)
    return batch

def simplify_genres(genre_str):
    """
    simplify the genre string of a single song to a list of mapped genres
    """
    if 'Need Manual Check' in genre_str:
        return None
    
    else: 
        genre_list = eval(genre_str)
        simplified_genres = set()
        
        genre_mapping = {
            'pop': 'Pop',
            'rock': 'Rock',
            'hip hop': 'Hip Hop',
            'rap': 'Hip Hop',
            'r&b': 'R&B',
            'electronic': 'Electronic/Dance',
            'edm': 'Electronic/Dance',
            'dance': 'Electronic/Dance',
            'country': 'Country',
            'jazz': 'Jazz',
            'reggae': 'Reggae',
            'latin': 'Latin',
            'classical': 'Classical'
        }
        
        for g in genre_list:
            g = g.lower()
            for k, v in genre_mapping.items():
                if k == g:
                    simplified_genres.add(v)
        
        return list(simplified_genres) if simplified_genres else None

# %%
input_folder = "output"
output_folder = "simplified_output"

os.makedirs(output_folder, exist_ok=True)

batch_list = os.listdir(input_folder)

for batch in batch_list:
    if batch.endswith(".csv"):
        file_path = os.path.join(input_folder, batch)
        
        if os.path.getsize(file_path) == 0:
            print(f"Empty file: {batch}")
            continue
                
        df = pd.read_csv(file_path)
        new_file_path = os.path.join(output_folder, batch)
        df2 = convert_song_genres(df)
        df2.to_csv(new_file_path, index=False)

print("파일 수정 및 저장이 완료되었습니다.")
# Out:
# 파일 수정 및 저장이 완료되었습니다.

# %%
df2.head()
# Out:
#          date  rank                  song_title           artist  \
# 0  2017-11-18   1.0                    Rockstar     Post Malone
# 1  2017-11-18   2.0                      Havana  Camila Cabello
# 2         NaN   NaN  Bodak Yellow (Money Moves)          Cardi B
# 3  2017-11-18   4.0              1-800-273-8255           Logic
# 4  2017-11-18   5.0                     Thunder  Imagine Dragons
#
#            genres
# 0  [Pop, Hip Hop]
# 1           [Pop]
# 2            None
# 3       [Hip Hop]
# 4     [Rock, Pop]

# %%
# merge all the files into one

import glob

files = os.path.join("simplified_output/", "genres_data_batch_*.csv")
joined_list = glob.glob(files)

joined_df = pd.concat([pd.read_csv(f) for f in joined_list], ignore_index=True)
joined_df
# Out:
#              date   rank            song_title           artist  \
# 0      2016-01-02    1.0                 Hello            Adele
# 1      2016-01-02    2.0                 Sorry    Justin Bieber
# 2      2016-01-02    3.0         Hotline Bling            Drake
# 3      2016-01-02    4.0         Love Yourself    Justin Bieber
# 4      2016-01-02    5.0     What Do You Mean?    Justin Bieber
# ...           ...    ...                   ...              ...
# 30595         NaN    NaN             Too Hotty  Quavo, Takeoff
# 30596  2017-11-18   97.0  All The Pretty Girls    Kenny Chesney
# 30597  2017-11-18   98.0             All On Me     Devin Dawson
# 30598  2017-11-18   99.0   More Girls Like You        Kip Moore
# 30599  2017-11-18  100.0              High End     Chris Brown
#
#                    genres
# 0                 ['Pop']
# 1                 ['Pop']
# 2             ['Hip Hop']
# 3                 ['Pop']
# 4                 ['Pop']
# ...                   ...
# 30595                 NaN
# 30596         ['Country']
# 30597                 NaN
# 30598         ['Country']
# 30599  ['R&B', 'Hip Hop']
#
# [30600 rows x 5 columns]

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30600 entries, 0 to 30599
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        29953 non-null  object
#  1   rank        29953 non-null  float64
#  2   song_title  30600 non-null  object
#  3   artist      30364 non-null  object
#  4   genres      23852 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Columns that need to be filled: 1) date, 2) rank, 3) artist 4) genres

# %%
len(df[joined_df['date'].isnull()]['song_title'].unique().tolist())
# Out:
# 63

# %%
# rank resets to every 100th song (since the index start from 0)

if any(df[joined_df['date'].isnull()].index % 100 == 0):
    joined_df['date'].bfill(inplace=True)
    joined_df['rank'].bfill(inplace=True)
else:
    joined_df['date'].ffill(inplace=True)
    joined_df['rank'].ffill(inplace=True)

# %% [markdown]
# All the unique lists of song turned out to be the song of 'XXXTENTACION'.
#
# According to the [Spotify artist page](https://open.spotify.com/artist/15UsOTVnJzReFVN1VCnxy4), the main genres of 'XXXTENTACION' are 'Hip Hop', 'R&B', and 'Rock'

# %%
df[joined_df['artist'].isnull()]['song_title'].unique().tolist()
# Out:
# ['Jocelyn Flores',
#  'F**k Love',
#  'Sad!',
#  'Changes',
#  'Moonlight',
#  'The Remedy For A Broken Heart (Why Am I So In Love)',
#  'Numb',
#  'Infinity (888)',
#  'Going Down!',
#  'Everybody Dies In Their Nightmares',
#  'Hope',
#  'Arms Around You',
#  'BAD!',
#  'whoa (mind in awe)',
#  'Guardian Angel',
#  "I Don't Let Go",
#  'One Minute',
#  'Train Food',
#  'What Are You So Afraid Of',
#  'Staring At The Sky',
#  'Difference (Interlude)',
#  'Sauce!',
#  'Bad Vibes Forever',
#  'Unsteady',
#  'Look At Me!',
#  'Revenge',
#  'Depression & Obsession',
#  'Save Me',
#  'Carry On']

# %%
if any(df[joined_df['artist'].isnull()]['song_title']):
    joined_df['artist'].fillna(value='XXXTENTACION', inplace=True)
    joined_df['genres'].fillna(value=['Hip Hop', 'R&B', 'Rock'], inplace=True)

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30600 entries, 0 to 30599
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        30600 non-null  object
#  1   rank        30600 non-null  float64
#  2   song_title  30600 non-null  object
#  3   artist      30600 non-null  object
#  4   genres      23852 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# There were still 6748 data that doesn't contain genre information.

# %%
df[joined_df['genres'].isnull()]['artist'].unique().tolist()
# Out:
# ['Jordan Smith',
#  'Silento',
#  'Cam',
#  'R. City ',
#  'Brenda Lee',
#  'OMI',
#  'iLoveMemphis',
#  'Emily Ann Roberts',
#  'DLOW',
#  'LOCASH',
#  'Rudimental ',
#  'Rachel Platten',
#  'Lil Dicky ',
#  'Andy Grammer',
#  'Macklemore ',
#  'Jordan Smith ',
#  'Granger Smith',
#  'Dawin',
#  'Lukas Graham',
#  'Mark Ronson ',
#  'Maren Morris',
#  'Chris Stapleton',
#  'DJ Luke Nasty',
#  'Chase Bryant',
#  'Cardi B',
#  'Portugal. The Man',
#  'J Balvin ',
#  'Luis Fonsi ',
#  'GoldLink ',
#  'LANCO',
#  nan,
#  'MA',
#  'Becky G ',
#  'Garth Brooks',
#  '6i',
#  'Lil ',
#  'Lil Peep',
#  'Machine Gun Kelly, ',
#  'Farruko, Nicki Minaj, Bad Bunny, 21 Savage ',
#  'Jake Paul ',
#  'Devin Dawson',
#  'Chloe Kohanski',
#  'Nat King Cole',
#  'Andy Williams',
#  'Burl Ives',
#  'Romeo Santos ',
#  'Natti Natasha ',
#  'Wham!',
#  'Ozuna ',
#  'Huncho Jack ',
#  'Huncho Jack',
#  'WALK THE MOON',
#  'Keala Settle ',
#  'Zac Efron ',
#  'Loren Allred',
#  'Maluma ',
#  'Hugh Jackman, Keala Settle, Zac Efron, Zendaya ',
#  'Lil Skies ',
#  'Jay Rock, Kendrick Lamar, Future ',
#  'Enrique Iglesias ',
#  'Empire Of The Sun',
#  'O.T. Genasis ',
#  'Belly ',
#  'Plies',
#  'Daddy Yankee',
#  "Derez De'Shon",
#  'Jordan Davis',
#  'SOB ',
#  'Daniel Caesar ',
#  'Blac Youngsta',
#  'High Valley',
#  'Nicky Jam ',
#  'Bad Wolves',
#  'Lin-Manuel Miranda ',
#  'Morgan Wallen ',
#  'Alice Merton',
#  'Ella Mai',
#  'Swae Lee ',
#  'Casper Magico, Nio Garcia, Darell, Nicky Jam, Ozuna ',
#  'David Lee Murphy ',
#  'Bhad Bhabie ',
#  'Reik ',
#  'Lil Skies',
#  'Kris Wu',
#  'Backstreet Boys',
#  'Becky G + Natti Natasha',
#  'Morgan Evans',
#  'Iggy Azalea Feauring Tyga',
#  'Lauren Daigle',
#  'lovelytheband',
#  'Dylan Scott',
#  'TK Kravitz ',
#  'Dennis Lloyd',
#  'Yella Beezy',
#  'Mitchell Tenpenny',
#  'H.E.R. ',
#  'Bryce Vine',
#  'Ozuna',
#  'Labrinth, Sia ',
#  'Machine Gun Kelly',
#  'Lil Peep ',
#  'Flipp Dinero',
#  'Jimmie Allen',
#  'Lil Mosey',
#  'Pardison Fontaine ',
#  'Bradley Cooper',
#  'Bad Bunny ',
#  'Dreezy ',
#  'Anuel AA ',
#  'City Girls ',
#  'AJR',
#  'Bobby Helms',
#  'Gene Autry',
#  'Dean Martin',
#  'The Ronettes',
#  'Jose Feliciano',
#  'Perry Como',
#  'Perry Como And The Fontane Sisters With Mitchell Ayres And His Orchestra',
#  'Bing Crosby',
#  'Darlene Love',
#  'Calboy',
#  'Elvis Presley',
#  'Frank Sinatra',
#  'Pinkfong',
#  'Midland',
#  'Bad Bunny',
#  'Young Greatness',
#  'MadeinTYO',
#  'Gesaffelstein ',
#  'Cody Johnson',
#  'Hikaru Utada ',
#  'Daddy Yankee ',
#  'Kacey Musgraves',
#  'YK Osiris',
#  'Riley Green',
#  'Michael Ray',
#  'John Mayer',
#  'City Girls',
#  'Lil Nas ',
#  'Morgan Wallen',
#  'Pedro Capo ',
#  'Joji',
#  'Mabel',
#  'Aventura',
#  'Five Finger Death Punch ',
#  'Lil Dicky',
#  'YG',
#  'Ed Sheeran ',
#  'Lunay, Daddy Yankee ',
#  'The Lumineers',
#  'Alan Walker',
#  'Jennifer Lopez',
#  'Yella Beezy, Gucci Mane ',
#  'Maluma',
#  'John Rich ',
#  'Bryce Vine ',
#  'Lil Tecca',
#  'SHAED',
#  'Blanco Brown',
#  'Sech, Darell, Nicky Jam, Ozuna ',
#  'Ali Gatie',
#  'Saweetie',
#  'Y2K ',
#  'Jhay Cortez, J Balvin ',
#  'Mustard featuring NAV, Playboi Carti ',
#  'Anuel AA, Daddy Yankee, Karol G, Ozuna ',
#  'Beyonce, SAINt JHN ',
#  'Grace ',
#  'Sarah Jeffery',
#  'Ambjaay',
#  'Matt Stell',
#  'Runaway June',
#  'for KING ',
#  'Tainy, Anuel AA ',
#  'Lil Mosey ',
#  'j-hope ',
#  'Layton Greene, Lil Baby, City Girls ',
#  'Tones And I',
#  'Lindsey Stirling',
#  'J Balvin',
#  'Internet Money, Lil Tecca ',
#  'Frank Ocean',
#  'Arizona Zervas',
#  'Rod Wave',
#  'Karol G ',
#  'Ant Saunders',
#  '24kGoldn',
#  'Trevor Daniel',
#  'Idina Menzel ',
#  'Rod Wave ',
#  'Russ ',
#  "Ghost Town DJ's",
#  'Kent Jones',
#  'Thurl Ravenscroft',
#  'JACKBOYS ',
#  'JACKBOYS, Pop Smoke ',
#  'Gabby Barrett ',
#  'Ingrid Andress',
#  'Garth Brooks ',
#  'Anuel AA',
#  'Ashe ',
#  'G Herbo ',
#  'Bad Bunny, Jowell ',
#  'Surfaces',
#  'Powfu ',
#  'BENEE ',
#  'SAINt JHN',
#  'Travis Denning',
#  'JP Sa',
#  'Arcangel ',
#  'Regard',
#  'THE SCOTTS, Travis Scott ',
#  'StaySolidRocky',
#  'Young T ',
#  'Adam Wakefield',
#  'Agust D',
#  'Surf Mesa ',
#  'HARDY ',
#  'Sleepy Hallow',
#  'Kid LAROI ',
#  'Tyla Yaweh ',
#  'Jawsh 685 ',
#  'J.I The Prince Of N.Y',
#  'Breland',
#  'Parker McCollum',
#  'Trevor Daniel ',
#  'Kane Brown With Swae Lee ',
#  'Hannah Huston',
#  'Kiiara',
#  'Nicky Jam',
#  'Alisan Porter',
#  'Topic ',
#  'J Balvin, Dua Lipa, Bad Bunny ',
#  'Machine Gun Kelly ',
#  '24kGoldn ',
#  'Jameson Rodgers',
#  'Nio Garcia ',
#  'Mulatto',
#  'Internet Money ',
#  'Money Man ',
#  'WhoHeem',
#  'Sech, Daddy Yankee ',
#  'Andrew Jannakos',
#  'VEDO',
#  'Keith Urban Duet With P!nk',
#  'YFN Lucci',
#  'Sada Baby ',
#  'Karol G',
#  'Niko Moon',
#  'Ritt Momney',
#  'Clairo',
#  'Yung Bleu ',
#  'Larray',
#  'BRS Kash',
#  'Saweetie ',
#  'The Kid LAROI',
#  'Farruko',
#  'Joel Corry ',
#  'DJ Chose ',
#  'The Kid LAROI ',
#  'CJ',
#  'Phoebe ',
#  'Michael Buble',
#  'Trey Lewis',
#  'Bing Crosby ',
#  'Donny Hathaway',
#  'Jackson 5',
#  'Gabby Barrett',
#  'Popp Hunna',
#  'DDG',
#  'All Time Low ',
#  'Parmalee ',
#  'Pooh Shiesty ',
#  'Glass Animals',
#  'Erica Banks',
#  'SpotemGottem ',
#  'Ant Clemons ',
#  'Tenille Arts',
#  'Tom MacDonald',
#  'Coi Leray ',
#  'Myke Towers ',
#  'Morray',
#  'D.R.A.M. ',
#  'Jacob Sartorius',
#  'Masked Wolf',
#  'Kali Uchis',
#  'Clinton Kane',
#  'Mooski',
#  'Elle King ',
#  'Silk Sonic (Bruno Mars ',
#  'Juice WRLD, Clever ',
#  'ROSE',
#  '42 Dugg ',
#  'Duncan Laurence',
#  'Ryan Hurd With Maren Morris',
#  'Broadway For Orlando',
#  'Kane Brown',
#  'David Nail',
#  'Gera M',
#  'Cico P',
#  'J. Cole, 21 Savage ',
#  'J. Cole, Bas ',
#  'Bella Poarch',
#  'Internet Money, Don Toliver ',
#  'Lainey Wilson',
#  'Cochise ',
#  'Rauw Alejandro',
#  'MO3 ',
#  'Willow ',
#  'Los Legendarios, Wisin ',
#  'Regard ',
#  'Elvie Shane',
#  'Maneskin',
#  'Aaron Lewis',
#  'Big Red Machine ',
#  'Wizkid ',
#  'Tai Verdes',
#  'Jameson Rodgers ',
#  'BIA ',
#  'Mora, Bad Bunny ',
#  'Smiley ',
#  'Belly, The Weeknd ',
#  'EST Gee',
#  'EST Gee ',
#  'Aventura ',
#  'Yung Bleu, Chris Brown ',
#  'Capella Grey',
#  'Jordan Davis ',
#  'KSI ',
#  'Nessa Barrett',
#  'Sueco',
#  'Ben Rector',
#  'Chloe',
#  'THE AN',
#  'Lisa',
#  'CKay',
#  'Bl',
#  'Eslabon Armado ',
#  'Skylar Grey, Polo G, Mozzy ',
#  'Ivan Cornejo',
#  'Nardo Wick ',
#  'Tainy, Bad Bunny ',
#  'Realestk',
#  'Jimmie Allen ',
#  'Oliver Tree',
#  'Priscilla Block',
#  'Loza Ale',
#  'NEIKED ',
#  'Grupo Firme',
#  'Bryson Gray ',
#  'Latto',
#  'Jennifer Lopez ',
#  'Enrique Iglesias Feat. Wisin or Tinashe ',
#  'Marc E. Bassy ',
#  'Carlos Vives ',
#  'Dae Dae',
#  'Lil Yachty',
#  'Rob $tone ',
#  'Young Thug And Travis Scott ',
#  'DJ Drama ',
#  'Tucker Beathard',
#  'DJ ESCO ',
#  'William Michael Morgan',
#  'Artists Of Then, Now ',
#  'Zay Hilfigerrr ',
#  'YFN Lucci ',
#  'Fitz And The Tantrums',
#  'Frenship ',
#  'CL',
#  'PIKOTARO',
#  'Jon Bellion',
#  'Pentatoni',
#  'Russ',
#  'Leonard Cohen',
#  'Starley',
#  "Auli'i Cravalho",
#  'Dwayne Johnson',
#  "Opetaia Foa'i ",
#  'Sundance Head',
#  'Wham! ',
#  'George Michael',
#  'KYLE ',
#  'KALEO',
#  'Ugly God',
#  'Marian Hill',
#  'Hey Violet',
#  'Panic! At The Disco',
#  'Sage The Gemini',
#  'Romeo Santos',
#  'Ayo ',
#  'DJ Suede The Remi',
#  "Rag'n'Bone Man",
#  'Curren$Y ',
#  'Lord Huron',
#  'Lauren Duski',
#  'Chris Blue',
#  'Wisin ',
#  'Plies ',
#  'China Anne McClain, Thomas Doherty ',
#  'Descendants 2 Cast',
#  'The Revivalists',
#  'RiceGum ',
#  'Bhad Bhabie',
#  'Maren Morris ',
#  'Quavo, Takeoff ']
